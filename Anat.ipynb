# %% [markdown]
# # Movie Recommendation System
#
# By: Anat Jacobson, Stephanie Ciaccia and Charlie Jin
#
# ---

# %% [markdown]
# ### Overview:
#
# Build a model that provides top 5 movie recommendations to a user, based on their ratings of other movies.
#
# The MovieLens dataset is a "classic" recommendation system dataset, that is used in numerous academic papers and machine learning proofs-of-concept. You will need to create the specific details about how the user will provide their ratings of other movies, in addition to formulating a more specific business problem within the general context of "recommending movies".
#
# ### Introduction and Business Case:
#
# ### Business Understandings:
# #### Applications:
# #### Data:
# ### Methodology:
#
# ---
#
# ## Data Exploration and Analysis
# Importing all packages needed

# %%
#imports
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.dummy import DummyClassifier, DummyRegressor
from sklearn.metrics import log_loss
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

from imblearn.pipeline import Pipeline as ImPipeline

# %% [markdown]
# ### Import CSVs, Merge, and Clean all Data Needed
# 4 Datasets imported:
# - Movies:
# - Links:
# - Ratings:
# - Tags:

# %%
#Import all relevant data tables
movies_df = pd.read_csv('data/movies.csv')
links_df = pd.read_csv('data/links.csv')
ratings_df = pd.read_csv('data/ratings.csv')
tags_df = pd.read_csv('data/tags.csv')

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_df.shape
# Out:
# (9742, 3)

# %%
links_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links_df.shape
# Out:
# (9742, 3)

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings_df.shape
# Out:
# (100836, 4)

# %%
tags_df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags_df.shape
# Out:
# (3683, 4)

# %%
#Merging links and movies
links_and_movies = pd.merge(movies_df, links_df, 'left', on = 'movieId')
links_and_movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres   imdbId    tmdbId
# 0     Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1                      Adventure|Children|Fantasy   113497    8844.0
# 2                                  Comedy|Romance   113228   15602.0
# 3                            Comedy|Drama|Romance   114885   31357.0
# 4                                          Comedy   113041   11862.0
# ...                                           ...      ...       ...
# 9737              Action|Animation|Comedy|Fantasy  5476944  432131.0
# 9738                     Animation|Comedy|Fantasy  5914996  445030.0
# 9739                                        Drama  6397426  479308.0
# 9740                             Action|Animation  8391976  483455.0
# 9741                                       Comedy   101726   37891.0
#
# [9742 rows x 5 columns]

# %%
movies_and_ratings = pd.merge(links_and_movies, ratings_df, 'left', on = 'movieId')
movies_and_ratings
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100849   193581  Black Butler: Book of the Atlantic (2017)
# 100850   193583               No Game No Life: Zero (2017)
# 100851   193585                               Flint (2017)
# 100852   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100853   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 2       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 3       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 4       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...                                             ...      ...       ...
# 100849              Action|Animation|Comedy|Fantasy  5476944  432131.0
# 100850                     Animation|Comedy|Fantasy  5914996  445030.0
# 100851                                        Drama  6397426  479308.0
# 100852                             Action|Animation  8391976  483455.0
# 100853                                       Comedy   101726   37891.0
#
#         userId  rating     timestamp
# 0          1.0     4.0  9.649827e+08
# 1          5.0     4.0  8.474350e+08
# 2          7.0     4.5  1.106636e+09
# 3         15.0     2.5  1.510578e+09
# 4         17.0     4.5  1.305696e+09
# ...        ...     ...           ...
# 100849   184.0     4.0  1.537109e+09
# 100850   184.0     3.5  1.537110e+09
# 100851   184.0     3.5  1.537110e+09
# 100852   184.0     3.5  1.537110e+09
# 100853   331.0     4.0  1.537158e+09
#
# [100854 rows x 8 columns]

# %%
full_df = pd.merge(movies_and_ratings, tags_df, 'left', on = 'movieId')
full_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    imdbId  tmdbId  userId_x  rating  timestamp_x  userId_y    tag  \
# 0  114709   862.0       1.0     4.0  964982703.0     336.0  pixar
# 1  114709   862.0       1.0     4.0  964982703.0     474.0  pixar
# 2  114709   862.0       1.0     4.0  964982703.0     567.0    fun
# 3  114709   862.0       5.0     4.0  847434962.0     336.0  pixar
# 4  114709   862.0       5.0     4.0  847434962.0     474.0  pixar
#
#     timestamp_y
# 0  1.139046e+09
# 1  1.137207e+09
# 2  1.525286e+09
# 3  1.139046e+09
# 4  1.137207e+09

# %%
full_df.shape
# Out:
# (285783, 11)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285783 entries, 0 to 285782
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   movieId      285783 non-null  int64
#  1   title        285783 non-null  object
#  2   genres       285783 non-null  object
#  3   imdbId       285783 non-null  int64
#  4   tmdbId       285770 non-null  float64
#  5   userId_x     285762 non-null  float64
#  6   rating       285762 non-null  float64
#  7   timestamp_x  285762 non-null  float64
#  8   userId_y     233234 non-null  float64
#  9   tag          233234 non-null  object
#  10  timestamp_y  233234 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 26.2+ MB

# %%
full_df.drop(full_df[full_df['userId_y'].isna()].index, inplace = True)
#this drops all the rows with NA. or we could drop the columns

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233234 entries, 0 to 285773
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   movieId      233234 non-null  int64
#  1   title        233234 non-null  object
#  2   genres       233234 non-null  object
#  3   imdbId       233234 non-null  int64
#  4   tmdbId       233234 non-null  float64
#  5   userId_x     233213 non-null  float64
#  6   rating       233213 non-null  float64
#  7   timestamp_x  233213 non-null  float64
#  8   userId_y     233234 non-null  float64
#  9   tag          233234 non-null  object
#  10  timestamp_y  233234 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 21.4+ MB

# %%
full_df.drop(full_df[full_df['rating'].isna()].index, inplace = True)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233213 entries, 0 to 285773
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   movieId      233213 non-null  int64
#  1   title        233213 non-null  object
#  2   genres       233213 non-null  object
#  3   imdbId       233213 non-null  int64
#  4   tmdbId       233213 non-null  float64
#  5   userId_x     233213 non-null  float64
#  6   rating       233213 non-null  float64
#  7   timestamp_x  233213 non-null  float64
#  8   userId_y     233213 non-null  float64
#  9   tag          233213 non-null  object
#  10  timestamp_y  233213 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 21.4+ MB

# %%
full_df.describe() #exploring that dataset
# Out:
#              movieId        imdbId         tmdbId       userId_x  \
# count  233213.000000  2.332130e+05  233213.000000  233213.000000
# mean    12319.999443  2.610632e+05    9378.277742     309.688191
# std     28243.919401  4.414411e+05   36943.139800     178.206387
# min         1.000000  1.234900e+04      11.000000       1.000000
# 25%       296.000000  1.103570e+05     278.000000     156.000000
# 50%      1198.000000  1.109120e+05     680.000000     309.000000
# 75%      4638.000000  1.724950e+05    1892.000000     460.000000
# max    193565.000000  5.580390e+06  503475.000000     610.000000
#
#               rating   timestamp_x       userId_y   timestamp_y
# count  233213.000000  2.332130e+05  233213.000000  2.332130e+05
# mean        3.966535  1.213524e+09     470.683564  1.384774e+09
# std         0.968637  2.250448e+08     153.329632  1.534621e+08
# min         0.500000  8.281246e+08       2.000000  1.137179e+09
# 25%         3.500000  1.017365e+09     424.000000  1.242494e+09
# 50%         4.000000  1.217325e+09     477.000000  1.457901e+09
# 75%         5.000000  1.443201e+09     599.000000  1.498457e+09
# max         5.000000  1.537799e+09     610.000000  1.537099e+09

# %%
full_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    imdbId  tmdbId  userId_x  rating  timestamp_x  userId_y    tag  \
# 0  114709   862.0       1.0     4.0  964982703.0     336.0  pixar
# 1  114709   862.0       1.0     4.0  964982703.0     474.0  pixar
# 2  114709   862.0       1.0     4.0  964982703.0     567.0    fun
# 3  114709   862.0       5.0     4.0  847434962.0     336.0  pixar
# 4  114709   862.0       5.0     4.0  847434962.0     474.0  pixar
#
#     timestamp_y
# 0  1.139046e+09
# 1  1.137207e+09
# 2  1.525286e+09
# 3  1.139046e+09
# 4  1.137207e+09

# %% [markdown]
# What do we have?
# - We have movies and then features
# - Features are:
#     - Genere
#     - Rating
#     - Tag
#
# Each movie should probably only be only 1 row.
# Have to compare by looking at the cosine of the angle between them.
# Closer to 1 is the more similar they are. Each row is a vector

# %%
full_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    imdbId  tmdbId  userId_x  rating  timestamp_x  userId_y    tag  \
# 0  114709   862.0       1.0     4.0  964982703.0     336.0  pixar
# 1  114709   862.0       1.0     4.0  964982703.0     474.0  pixar
# 2  114709   862.0       1.0     4.0  964982703.0     567.0    fun
# 3  114709   862.0       5.0     4.0  847434962.0     336.0  pixar
# 4  114709   862.0       5.0     4.0  847434962.0     474.0  pixar
#
#     timestamp_y
# 0  1.139046e+09
# 1  1.137207e+09
# 2  1.525286e+09
# 3  1.139046e+09
# 4  1.137207e+09

# %% [markdown]
# one hot encode -- > genere, tag --> dummy or one hot encode

# %%
#subpipe_numeric = Pipeline(steps=[('ss', StandardScaler())])
#subpipe_categorical = Pipeline(steps=[('ohe', OneHotEncoder(sparse=False, handle_unknown= 'ignore'))])
#CT = ColumnTransformer(transformers=[('subpipe_numeric', subpipe_numeric, scale),
#                                         ('subpipe_categorical', subpipe_categorical, cat)],
#                           remainder='passthrough')

# %%
ratings_df['userId'].min()
# Out:
# 1

# %%
ratings_df['userId'].max() #go according to ratings...
# Out:
# 610

# %%
ratings_df #have to fix this dataframe . Ratings is the main one? Based on user IDb
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
full_df['genres'].value_counts()
# Out:
# Comedy|Crime|Drama|Thriller           56851
# Action|Crime|Drama|Thriller           16725
# Action|Adventure|Sci-Fi               11939
# Drama                                  6242
# Comedy                                 5486
#                                       ...
# Drama|Fantasy|Horror                      1
# Animation|Children|Musical                1
# Drama|Thriller|Western                    1
# Adventure|Crime|Drama|Thriller            1
# Comedy|Crime|Drama|Mystery|Romance        1
# Name: genres, Length: 370, dtype: int64

# %%
genres = (full_df.genres.str.split('|', expand=True)
            .stack()
            .to_frame(name='genres'))

genres.index = genres.index.droplevel(1)

# %%
genres2 = full_df['genres'].str.split('|', expand=True)
genres2
# Out:
#                 0          1         2       3        4     5     6
# 0       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 1       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 2       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 3       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 4       Adventure  Animation  Children  Comedy  Fantasy  None  None
# ...           ...        ...       ...     ...      ...   ...   ...
# 285745     Action  Adventure  Children  Sci-Fi     None  None  None
# 285770     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285771     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285772     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285773     Action  Animation    Comedy  Sci-Fi     None  None  None
#
# [233213 rows x 7 columns]

# %%
genres2[6].value_counts()
# Out:
# IMAX       3718
# Mystery      97
# Name: 6, dtype: int64

# %%
df = full_df.join(genres2)

# %%
df
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 285745   187595  Solo: A Star Wars Story (2018)
# 285770   193565       Gintama: The Movie (2010)
# 285771   193565       Gintama: The Movie (2010)
# 285772   193565       Gintama: The Movie (2010)
# 285773   193565       Gintama: The Movie (2010)
#
#                                              genres   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 2       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 3       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 4       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...                                             ...      ...       ...
# 285745             Action|Adventure|Children|Sci-Fi  3778644  348350.0
# 285770               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285771               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285772               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285773               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
#
#         userId_x  rating   timestamp_x  userId_y        tag   timestamp_y  \
# 0            1.0     4.0  9.649827e+08     336.0      pixar  1.139046e+09
# 1            1.0     4.0  9.649827e+08     474.0      pixar  1.137207e+09
# 2            1.0     4.0  9.649827e+08     567.0        fun  1.525286e+09
# 3            5.0     4.0  8.474350e+08     336.0      pixar  1.139046e+09
# 4            5.0     4.0  8.474350e+08     474.0      pixar  1.137207e+09
# ...          ...     ...           ...       ...        ...           ...
# 285745     586.0     5.0  1.529900e+09      62.0  star wars  1.528935e+09
# 285770     184.0     3.5  1.537099e+09     184.0      anime  1.537099e+09
# 285771     184.0     3.5  1.537099e+09     184.0     comedy  1.537099e+09
# 285772     184.0     3.5  1.537099e+09     184.0    gintama  1.537099e+09
# 285773     184.0     3.5  1.537099e+09     184.0   remaster  1.537099e+09
#
#                 0          1         2       3        4     5     6
# 0       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 1       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 2       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 3       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 4       Adventure  Animation  Children  Comedy  Fantasy  None  None
# ...           ...        ...       ...     ...      ...   ...   ...
# 285745     Action  Adventure  Children  Sci-Fi     None  None  None
# 285770     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285771     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285772     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285773     Action  Animation    Comedy  Sci-Fi     None  None  None
#
# [233213 rows x 18 columns]

# %%
df
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 285745   187595  Solo: A Star Wars Story (2018)
# 285770   193565       Gintama: The Movie (2010)
# 285771   193565       Gintama: The Movie (2010)
# 285772   193565       Gintama: The Movie (2010)
# 285773   193565       Gintama: The Movie (2010)
#
#                                              genres   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 2       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 3       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 4       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...                                             ...      ...       ...
# 285745             Action|Adventure|Children|Sci-Fi  3778644  348350.0
# 285770               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285771               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285772               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285773               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
#
#         userId_x  rating   timestamp_x  userId_y        tag   timestamp_y  \
# 0            1.0     4.0  9.649827e+08     336.0      pixar  1.139046e+09
# 1            1.0     4.0  9.649827e+08     474.0      pixar  1.137207e+09
# 2            1.0     4.0  9.649827e+08     567.0        fun  1.525286e+09
# 3            5.0     4.0  8.474350e+08     336.0      pixar  1.139046e+09
# 4            5.0     4.0  8.474350e+08     474.0      pixar  1.137207e+09
# ...          ...     ...           ...       ...        ...           ...
# 285745     586.0     5.0  1.529900e+09      62.0  star wars  1.528935e+09
# 285770     184.0     3.5  1.537099e+09     184.0      anime  1.537099e+09
# 285771     184.0     3.5  1.537099e+09     184.0     comedy  1.537099e+09
# 285772     184.0     3.5  1.537099e+09     184.0    gintama  1.537099e+09
# 285773     184.0     3.5  1.537099e+09     184.0   remaster  1.537099e+09
#
#                 0          1         2       3        4     5     6
# 0       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 1       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 2       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 3       Adventure  Animation  Children  Comedy  Fantasy  None  None
# 4       Adventure  Animation  Children  Comedy  Fantasy  None  None
# ...           ...        ...       ...     ...      ...   ...   ...
# 285745     Action  Adventure  Children  Sci-Fi     None  None  None
# 285770     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285771     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285772     Action  Animation    Comedy  Sci-Fi     None  None  None
# 285773     Action  Animation    Comedy  Sci-Fi     None  None  None
#
# [233213 rows x 18 columns]

# %% [markdown]
# Make year own column. Do this through a loop or the way below.

# %%
full_df['year'] = full_df['title'].str[-6:]
full_df
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 285745   187595  Solo: A Star Wars Story (2018)
# 285770   193565       Gintama: The Movie (2010)
# 285771   193565       Gintama: The Movie (2010)
# 285772   193565       Gintama: The Movie (2010)
# 285773   193565       Gintama: The Movie (2010)
#
#                                              genres   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 2       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 3       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 4       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...                                             ...      ...       ...
# 285745             Action|Adventure|Children|Sci-Fi  3778644  348350.0
# 285770               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285771               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285772               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285773               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
#
#         userId_x  rating   timestamp_x  userId_y        tag   timestamp_y  \
# 0            1.0     4.0  9.649827e+08     336.0      pixar  1.139046e+09
# 1            1.0     4.0  9.649827e+08     474.0      pixar  1.137207e+09
# 2            1.0     4.0  9.649827e+08     567.0        fun  1.525286e+09
# 3            5.0     4.0  8.474350e+08     336.0      pixar  1.139046e+09
# 4            5.0     4.0  8.474350e+08     474.0      pixar  1.137207e+09
# ...          ...     ...           ...       ...        ...           ...
# 285745     586.0     5.0  1.529900e+09      62.0  star wars  1.528935e+09
# 285770     184.0     3.5  1.537099e+09     184.0      anime  1.537099e+09
# 285771     184.0     3.5  1.537099e+09     184.0     comedy  1.537099e+09
# 285772     184.0     3.5  1.537099e+09     184.0    gintama  1.537099e+09
# 285773     184.0     3.5  1.537099e+09     184.0   remaster  1.537099e+09
#
#           year
# 0       (1995)
# 1       (1995)
# 2       (1995)
# 3       (1995)
# 4       (1995)
# ...        ...
# 285745  (2018)
# 285770  (2010)
# 285771  (2010)
# 285772  (2010)
# 285773  (2010)
#
# [233213 rows x 12 columns]

# %%
#Title without year
full_df['real_title'] = full_df['title'].str[:-6]
full_df
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 285745   187595  Solo: A Star Wars Story (2018)
# 285770   193565       Gintama: The Movie (2010)
# 285771   193565       Gintama: The Movie (2010)
# 285772   193565       Gintama: The Movie (2010)
# 285773   193565       Gintama: The Movie (2010)
#
#                                              genres   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 2       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 3       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 4       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...                                             ...      ...       ...
# 285745             Action|Adventure|Children|Sci-Fi  3778644  348350.0
# 285770               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285771               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285772               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
# 285773               Action|Animation|Comedy|Sci-Fi  1636780   71172.0
#
#         userId_x  rating   timestamp_x  userId_y        tag   timestamp_y  \
# 0            1.0     4.0  9.649827e+08     336.0      pixar  1.139046e+09
# 1            1.0     4.0  9.649827e+08     474.0      pixar  1.137207e+09
# 2            1.0     4.0  9.649827e+08     567.0        fun  1.525286e+09
# 3            5.0     4.0  8.474350e+08     336.0      pixar  1.139046e+09
# 4            5.0     4.0  8.474350e+08     474.0      pixar  1.137207e+09
# ...          ...     ...           ...       ...        ...           ...
# 285745     586.0     5.0  1.529900e+09      62.0  star wars  1.528935e+09
# 285770     184.0     3.5  1.537099e+09     184.0      anime  1.537099e+09
# 285771     184.0     3.5  1.537099e+09     184.0     comedy  1.537099e+09
# 285772     184.0     3.5  1.537099e+09     184.0    gintama  1.537099e+09
# 285773     184.0     3.5  1.537099e+09     184.0   remaster  1.537099e+09
#
#           year                real_title
# 0       (1995)                Toy Story
# 1       (1995)                Toy Story
# 2       (1995)                Toy Story
# 3       (1995)                Toy Story
# 4       (1995)                Toy Story
# ...        ...                       ...
# 285745  (2018)  Solo: A Star Wars Story
# 285770  (2010)       Gintama: The Movie
# 285771  (2010)       Gintama: The Movie
# 285772  (2010)       Gintama: The Movie
# 285773  (2010)       Gintama: The Movie
#
# [233213 rows x 13 columns]

# %% [markdown]
# # Ignore All below:

# %%
title = full_df['title'].str.split('(', expand=True)
title
# Out:
#                                0      1     2     3
# 0                     Toy Story   1995)  None  None
# 1                     Toy Story   1995)  None  None
# 2                     Toy Story   1995)  None  None
# 3                     Toy Story   1995)  None  None
# 4                     Toy Story   1995)  None  None
# ...                          ...    ...   ...   ...
# 285745  Solo: A Star Wars Story   2018)  None  None
# 285770       Gintama: The Movie   2010)  None  None
# 285771       Gintama: The Movie   2010)  None  None
# 285772       Gintama: The Movie   2010)  None  None
# 285773       Gintama: The Movie   2010)  None  None
#
# [233213 rows x 4 columns]

# %%
title[3].value_counts()
# Out:
# 1994)    4655
# 2002)     185
# 1992)      14
# 2005)       5
# 1945)       2
# 1998)       1
# Name: 3, dtype: int64

# %%
title.loc[title[3] == '1994)']
# Out:
#                              0                          1       2      3
# 23286  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# 23287  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# 23288  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# 23289  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# 23290  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# ...                        ...                        ...     ...    ...
# 27936  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# 27937  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# 27938  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# 27939  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
# 27940  Léon: The Professional   a.k.a. The Professional)   Léon)   1994)
#
# [4655 rows x 4 columns]

# %%
title.loc[title[3].notnull()]
# Out:
#                               0                              1  \
# 23286   Léon: The Professional       a.k.a. The Professional)
# 23287   Léon: The Professional       a.k.a. The Professional)
# 23288   Léon: The Professional       a.k.a. The Professional)
# 23289   Léon: The Professional       a.k.a. The Professional)
# 23290   Léon: The Professional       a.k.a. The Professional)
# ...                         ...                            ...
# 242318          Lady Vengeance   Sympathy for Lady Vengeance)
# 242319          Lady Vengeance   Sympathy for Lady Vengeance)
# 242320          Lady Vengeance   Sympathy for Lady Vengeance)
# 242321          Lady Vengeance   Sympathy for Lady Vengeance)
# 242322          Lady Vengeance   Sympathy for Lady Vengeance)
#
#                               2      3
# 23286                    Léon)   1994)
# 23287                    Léon)   1994)
# 23288                    Léon)   1994)
# 23289                    Léon)   1994)
# 23290                    Léon)   1994)
# ...                         ...    ...
# 242318  Chinjeolhan geumjassi)   2005)
# 242319  Chinjeolhan geumjassi)   2005)
# 242320  Chinjeolhan geumjassi)   2005)
# 242321  Chinjeolhan geumjassi)   2005)
# 242322  Chinjeolhan geumjassi)   2005)
#
# [4862 rows x 4 columns]

# %%
nulls = title.loc[title[2].notnull()]

# %%
nulls
# Out:
#                                   0                              1      2  \
# 2383    City of Lost Children, The   Cité des enfants perdus, La)   1995)
# 2384    City of Lost Children, The   Cité des enfants perdus, La)   1995)
# 2385    City of Lost Children, The   Cité des enfants perdus, La)   1995)
# 2386    City of Lost Children, The   Cité des enfants perdus, La)   1995)
# 2387    City of Lost Children, The   Cité des enfants perdus, La)   1995)
# ...                             ...                            ...    ...
# 279973                 Angel's Egg              Tenshi no tamago)   1985)
# 279974                 Angel's Egg              Tenshi no tamago)   1985)
# 279975                 Angel's Egg              Tenshi no tamago)   1985)
# 280905             The Rabbi's Cat             Le chat du rabbin)   2011)
# 280906             The Rabbi's Cat             Le chat du rabbin)   2011)
#
#            3
# 2383    None
# 2384    None
# 2385    None
# 2386    None
# 2387    None
# ...      ...
# 279973  None
# 279974  None
# 279975  None
# 280905  None
# 280906  None
#
# [15553 rows x 4 columns]

# %%
nulls2 = nulls[0] + "(" + nulls[1]

# %%
pd.DataFrame(nulls2)
# Out:
#                                                         0
# 2383    City of Lost Children, The (Cité des enfants p...
# 2384    City of Lost Children, The (Cité des enfants p...
# 2385    City of Lost Children, The (Cité des enfants p...
# 2386    City of Lost Children, The (Cité des enfants p...
# 2387    City of Lost Children, The (Cité des enfants p...
# ...                                                   ...
# 279973                    Angel's Egg (Tenshi no tamago)
# 279974                    Angel's Egg (Tenshi no tamago)
# 279975                    Angel's Egg (Tenshi no tamago)
# 280905               The Rabbi's Cat (Le chat du rabbin)
# 280906               The Rabbi's Cat (Le chat du rabbin)
#
# [15553 rows x 1 columns]

# %%
nulls3 = title.loc[title[3].notnull()]
nulls3
# Out:
#                               0                              1  \
# 23286   Léon: The Professional       a.k.a. The Professional)
# 23287   Léon: The Professional       a.k.a. The Professional)
# 23288   Léon: The Professional       a.k.a. The Professional)
# 23289   Léon: The Professional       a.k.a. The Professional)
# 23290   Léon: The Professional       a.k.a. The Professional)
# ...                         ...                            ...
# 242318          Lady Vengeance   Sympathy for Lady Vengeance)
# 242319          Lady Vengeance   Sympathy for Lady Vengeance)
# 242320          Lady Vengeance   Sympathy for Lady Vengeance)
# 242321          Lady Vengeance   Sympathy for Lady Vengeance)
# 242322          Lady Vengeance   Sympathy for Lady Vengeance)
#
#                               2      3
# 23286                    Léon)   1994)
# 23287                    Léon)   1994)
# 23288                    Léon)   1994)
# 23289                    Léon)   1994)
# 23290                    Léon)   1994)
# ...                         ...    ...
# 242318  Chinjeolhan geumjassi)   2005)
# 242319  Chinjeolhan geumjassi)   2005)
# 242320  Chinjeolhan geumjassi)   2005)
# 242321  Chinjeolhan geumjassi)   2005)
# 242322  Chinjeolhan geumjassi)   2005)
#
# [4862 rows x 4 columns]

# %%
nulls4 = nulls3[0] + "(" + nulls3[1] + "(" + nulls3[2]
New_df = pd.DataFrame(nulls4)

New_df['Years'] = pd.DataFrame(nulls3[3])
#this is dataframe with nulls from all columns
# Out:
#                                                         0  Years
# 23286   Léon: The Professional (a.k.a. The Professiona...  1994)
# 23287   Léon: The Professional (a.k.a. The Professiona...  1994)
# 23288   Léon: The Professional (a.k.a. The Professiona...  1994)
# 23289   Léon: The Professional (a.k.a. The Professiona...  1994)
# 23290   Léon: The Professional (a.k.a. The Professiona...  1994)
# ...                                                   ...    ...
# 242318  Lady Vengeance (Sympathy for Lady Vengeance) (...  2005)
# 242319  Lady Vengeance (Sympathy for Lady Vengeance) (...  2005)
# 242320  Lady Vengeance (Sympathy for Lady Vengeance) (...  2005)
# 242321  Lady Vengeance (Sympathy for Lady Vengeance) (...  2005)
# 242322  Lady Vengeance (Sympathy for Lady Vengeance) (...  2005)
#
# [4862 rows x 2 columns]

# %%
dropped_df = title.loc[title[2].isnull()]

# %%
dropped_df
# Out:
#                                0      1     2     3
# 0                     Toy Story   1995)  None  None
# 1                     Toy Story   1995)  None  None
# 2                     Toy Story   1995)  None  None
# 3                     Toy Story   1995)  None  None
# 4                     Toy Story   1995)  None  None
# ...                          ...    ...   ...   ...
# 285745  Solo: A Star Wars Story   2018)  None  None
# 285770       Gintama: The Movie   2010)  None  None
# 285771       Gintama: The Movie   2010)  None  None
# 285772       Gintama: The Movie   2010)  None  None
# 285773       Gintama: The Movie   2010)  None  None
#
# [217660 rows x 4 columns]

# %%
dropped_df.append(New_df, ignore_index = True)
# Out:
#                                                         0      1     2     3  \
# 0                                              Toy Story   1995)  None  None
# 1                                              Toy Story   1995)  None  None
# 2                                              Toy Story   1995)  None  None
# 3                                              Toy Story   1995)  None  None
# 4                                              Toy Story   1995)  None  None
# ...                                                   ...    ...   ...   ...
# 222517  Lady Vengeance (Sympathy for Lady Vengeance) (...    NaN   NaN   NaN
# 222518  Lady Vengeance (Sympathy for Lady Vengeance) (...    NaN   NaN   NaN
# 222519  Lady Vengeance (Sympathy for Lady Vengeance) (...    NaN   NaN   NaN
# 222520  Lady Vengeance (Sympathy for Lady Vengeance) (...    NaN   NaN   NaN
# 222521  Lady Vengeance (Sympathy for Lady Vengeance) (...    NaN   NaN   NaN
#
#         Years
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 222517  2005)
# 222518  2005)
# 222519  2005)
# 222520  2005)
# 222521  2005)
#
# [222522 rows x 5 columns]
